# %%
import pandas as pd
import numpy as np

#reading the CSV file containing and displaying it
df=pd.read_csv('/Users/ad0507/Downloads/VAD Project/Dataset Uncleaned/Hospital_Dataset.csv')
df.head()
# Out:
# /var/folders/k7/lb_86v_x1_gfg1v69zm05hb80000gn/T/ipykernel_53396/350403674.py:5: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/Users/ad0507/Downloads/VAD Project/Dataset Uncleaned/Hospital_Dataset.csv')
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         New York City           Bronx                     7000006.0
# 1         New York City           Bronx                     7000006.0
# 2         New York City           Bronx                     7000006.0
# 3         New York City           Bronx                     7000006.0
# 4         New York City           Bronx                     7000006.0
#
#    Permanent Facility Id                                      Facility Name  \
# 0                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 1                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# ...

# %%
#check the number of columns and non-nulls 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Hospital Service Area                39907 non-null  object
#  1   Hospital County                      39907 non-null  object
#  2   Operating Certificate Number         39907 non-null  float64
#  3   Permanent Facility Id                39907 non-null  float64
#  4   Facility Name                        40000 non-null  object
#  5   Age Group                            40000 non-null  object
#  6   Zip Code - 3 digits                  39065 non-null  object
#  7   Gender                               40000 non-null  object
#  8   Race                                 40000 non-null  object
#  9   Ethnicity                            40000 non-null  object
#  10  Length of Stay                       40000 non-null  object
# ...

# %%
#dropping irrelevant columns
df = df.drop(['CCSR Diagnosis Code', 'CCSR Diagnosis Description','CCSR Procedure Code','CCSR Procedure Description','Payment Typology 1','Payment Typology 2','Payment Typology 3','Birth Weight'], axis=1)

# %%
#check the dataset after columns are dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Hospital Service Area                39907 non-null  object
#  1   Hospital County                      39907 non-null  object
#  2   Operating Certificate Number         39907 non-null  float64
#  3   Permanent Facility Id                39907 non-null  float64
#  4   Facility Name                        40000 non-null  object
#  5   Age Group                            40000 non-null  object
#  6   Zip Code - 3 digits                  39065 non-null  object
#  7   Gender                               40000 non-null  object
#  8   Race                                 40000 non-null  object
#  9   Ethnicity                            40000 non-null  object
#  10  Length of Stay                       40000 non-null  object
# ...

# %%
df.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         New York City           Bronx                     7000006.0
# 1         New York City           Bronx                     7000006.0
# 2         New York City           Bronx                     7000006.0
# 3         New York City           Bronx                     7000006.0
# 4         New York City           Bronx                     7000006.0
#
#    Permanent Facility Id                                      Facility Name  \
# 0                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 1                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 2                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 3                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 4                 1168.0       Montefiore Medical Center-Wakefield Hospital
#
#   Age Group Zip Code - 3 digits Gender                    Race  \
# ...

# %%
#saved the dataset
#save the cleaned dataset to a new CSV file
cleaned_data_path = '/Users/ad0507/Downloads/VAD Project/DatasetsCleaned /Hospital_Dataset.xlsx'
df.to_csv(cleaned_data_path, index=False)
