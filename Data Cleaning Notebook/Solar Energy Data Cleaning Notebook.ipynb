# %%
import pandas as pd
import numpy as np

#reading the CSV file containing solar energy data into a pandas DataFrame
df=pd.read_csv('/Users/ad0507/Downloads/VAD Project/Dataset Uncleaned/Solar Energy.csv')

#displaying the first 5 rows of the DataFrame to preview the data
df.head()
# Out:
# /var/folders/k7/lb_86v_x1_gfg1v69zm05hb80000gn/T/ipykernel_11937/1501029806.py:4: DtypeWarning: Columns (1,3,4,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/Users/ad0507/Downloads/Solar Energy/Solar Energy.csv')
#   Reporting Period    Project Number Legacy Project Number CESIR Number  \
# 0       10/31/2024        0000830394                   NaN          NaN
# 1       10/31/2024        0000761568                   NaN          NaN
# 2       10/31/2024        0000274642                   NaN          NaN
# 3       10/31/2024        0000653576                   NaN          NaN
# 4       10/31/2024  2013-542628-Sola                   NaN          NaN
#
#   Street Address             City       County State ZIP Code  \
# 0            NaN      Schenectady  Schenectady    NY    12309
# 1            NaN         Brooklyn        Kings    NY    11212
# 2            NaN  Port Washington       Nassau    NY    11050
# ...

# %%
#check for nulls and also the columns we have
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174306 entries, 0 to 174305
# Data columns (total 48 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   Reporting Period                                    174306 non-null  object
#  1   Project Number                                      174306 non-null  object
#  2   Legacy Project Number                               55290 non-null   object
#  3   CESIR Number                                        1807 non-null    object
#  4   Street Address                                      10422 non-null   object
#  5   City                                                174306 non-null  object
#  6   County                                              174305 non-null  object
#  7   State                                               174306 non-null  object
# ...

# %%
#define a threshold for dropping columns (e.g., drop columns with more than 50% null values)
threshold = 0.5
columns_to_keep = df.columns[df.isnull().mean() <= threshold]

#drop columns with more than 50% null values
filtered_data = df[columns_to_keep]

#check the shape of the dataset after dropping columns
filtered_data_shape = filtered_data.shape

#display the dataset
filtered_data_shape
# Out:
# (174306, 44)

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174306 entries, 0 to 174305
# Data columns (total 44 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   Reporting Period                                    174306 non-null  object
#  1   Project Number                                      174306 non-null  object
#  2   City                                                174306 non-null  object
#  3   County                                              174305 non-null  object
#  4   State                                               174306 non-null  object
#  5   ZIP Code                                            174306 non-null  object
#  6   Incorporated Municipality                           173565 non-null  object
#  7   Municipality Type                                   173565 non-null  object
# ...

# %%
#check the statistics for the columns
filtered_data.describe()
# Out:
#        Census Tract  Total Inverter Quantity  Total PV Module Quantity  \
# count  1.689390e+05            174190.000000             174183.000000
# mean   3.607320e+10                10.768787                110.435387
# std    3.195095e+07                21.520673                989.748549
# min    3.600100e+10                 0.000000                  0.000000
# 25%    3.605501e+10                 1.000000                 16.000000
# 50%    3.608105e+10                 2.000000                 23.000000
# 75%    3.610311e+10                18.000000                 32.000000
# max    3.612315e+10              6067.000000              29160.000000
#
#        Project Cost  Total NYSERDA Incentive  \
# count  1.743060e+05             1.742340e+05
# mean   9.364214e+04             1.626659e+04
# std    6.236872e+05             1.299988e+05
# min    0.000000e+00             0.000000e+00
# 25%    2.172000e+04             1.296000e+03
# 50%    3.131000e+04             2.442000e+03
# ...

# %%
#save the merged dataframe to a CSV file for Tableau
merged_output_path = "/Users/ad0507/Downloads/Solar Energy/Solar_Energy_Cleaned.csv"
filtered_data.to_csv(merged_output_path, index=False)
